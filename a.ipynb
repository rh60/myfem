# %% [markdown]
# *Funkce* $f(x)=1-\frac{x^2}{2}+\frac{x^4}{24}$

# %%
using Polynomials
p=Polynomial([1, 0, -1/factorial(2), 0, 1/factorial(4), 0, -1/factorial(6)])
# Out:
# Polynomial(1.0 - 0.5*x^2 + 0.041666666666666664*x^4 - 0.001388888888888889*x^6)

# %% [markdown]
# *má graf:*

# %%
using PyPlot
x = range(0,π,length=100)
y = p.(x)
plot(x,y)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x0000000043B93248>

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
